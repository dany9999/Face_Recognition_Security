# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Keras VGGFACE-2

# %%
# Most Recent One (Suggested)
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# Out:
# Collecting git+https://github.com/rcmalli/keras-vggface.git
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-o2dt3w_p
#   Running command git clone --filter=blob:none --quiet https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-o2dt3w_p
#   Resolved https://github.com/rcmalli/keras-vggface.git to commit bee35376e76e35d00aeec503f2f242611a97b38a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (1.25.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (1.11.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (3.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (9.4.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (2.12.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (1.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from keras-vggface==0.6) (6.0.1)

# %%
# !pip install keras_vggface
# Out:
# Requirement already satisfied: keras_vggface in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_vggface) (1.25.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.10/dist-packages (from keras_vggface) (1.11.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_vggface) (3.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from keras_vggface) (9.4.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras_vggface) (2.12.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_vggface) (1.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from keras_vggface) (6.0.1)

# %%
import numpy as np
from keras.preprocessing import image
from keras_vggface.vggface import VGGFace
from keras_vggface import utils
from tensorflow.keras.preprocessing.image import load_img, img_to_array


# tensorflow
model = VGGFace(model='resnet50') # default : VGG16 , you can use model='resnet50' or 'senet50'

# Change the image path with yours.
img = load_img('/content/drive/MyDrive/Colab_Notebooks/AICS_progetto/test_set_cropped/Fábio_Coentrão_5_face_0.jpg', target_size=(224, 224))
x =  img_to_array(img)
x = np.expand_dims(x, axis=0)
x = utils.preprocess_input(x, version=2) # or version=2
preds = model.predict(x)
pred = utils.decode_predictions(preds)




predicted_name = "'" + pred[0][0][0].split("'")[1] + "'"

predicted_name = str(predicted_name)


print('Predicted:', decoded_label)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b3a1dc87640> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# Predicted: ' F\xc3\xa1bio_Coentr\xc3\xa3o'

# %%
import os
from PIL import Image
import numpy as np
import tensorflow as tf
import re
from torchvision import transforms


def load_image(filename):
    img = load_img(filename, target_size=(224, 224))
    x =  img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = utils.preprocess_input(x, version=2) # or version=2
    return x

fpath = tf.keras.utils.get_file('rcmalli_vggface_labels_v2.npy',
                             "https://github.com/rcmalli/keras-vggface/releases/download/v2.0/rcmalli_vggface_labels_v2.npy",
                             cache_subdir="./")
LABELS = np.load(fpath)

dataset_dir =  "/content/drive/MyDrive/Colab_Notebooks/AICS_progetto/test_set_cropped/"

correct_predictions = 0
total_images = 0

for filename in os.listdir(dataset_dir):
    if filename.endswith(".jpg") or filename.endswith(".jpeg"):
        person_path = os.path.join(dataset_dir, filename)
        img = load_image(person_path)
        preds = model.predict(img)
        pred = utils.decode_predictions(preds)
        print(pred)
        pred_label = "'" + pred[0][0][0].split("'")[1] + "'"

        print("Immagine:", filename)
        print("Predizione del modello:", pred_label)
        correct_label = re.sub(r'_\d+_face_0\.jpg$', '', filename)
        print("Etichetta corretta:", correct_label)


        if correct_label in pred_label:
                correct_predictions += 1
                print("OK")
        '''
        else:
             with open('predizioni_errate.txt', 'a') as file:
              file.write(filename)
              file.write('\n')
        '''
        total_images += 1
        print("-------------------------->")


if total_images == 0:
    print("Nessuna immagine trovata nel dataset.")
else:
    test_accuracy = correct_predictions / total_images
    print('\n')
    print('\n')
    print("Test Accuracy:", test_accuracy)
    print("Numero di predizioni corrette:", correct_predictions)
    print("Numero di immagini processate:", total_images)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 1/1 [==============================] - 0s 201ms/step
# [[["b' Christian_De_Sica'", 0.9924144], ["b' Marco_Antonio_Sol\\xc3\\xads'", 0.0007362857], ["b' Mark_Ballas'", 0.00019361774], ["b' Bruno_Madinier'", 0.00015927518], ["b' Corrado_Passera'", 0.00014895886]]]
# Immagine: Christian_De_Sica_1_face_0.jpg
# Predizione del modello: ' Christian_De_Sica'
# Etichetta corretta: Christian_De_Sica
# OK
# -------------------------->
# 1/1 [==============================] - 0s 401ms/step
# [[["b' Paolo_Maldini'", 0.99994445], ["b' Dietmar_Beiersdorfer'", 8.785552e-06], ["b' Darko_Rundek'", 8.378198e-06], ["b' Roman_Polko'", 7.0135507e-06], ["b' Philippe_Caroit'", 5.4598154e-06]]]
# Immagine: Paolo_Maldini_4_face_0.jpg
# Predizione del modello: ' Paolo_Maldini'
# Etichetta corretta: Paolo_Maldini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 185ms/step
# [[["b' Robert_De_Niro'", 0.998938], ["b' Thierry_Ardisson'", 0.00019992223], ["b' Ron_Paul'", 5.686178e-05], ["b' Christian_Clavier'", 4.191193e-05], ["b' Davy_Russell'", 4.057559e-05]]]
# Immagine: Robert_De_Niro_1_face_0.jpg
# Predizione del modello: ' Robert_De_Niro'
# Etichetta corretta: Robert_De_Niro
# OK
# -------------------------->
# 1/1 [==============================] - 0s 196ms/step
# [[["b' Maurizio_Sarri'", 0.961244], ["b' \\xc3\\x81ngel_Acebes'", 0.0053943475], ["b' Josep_Antoni_Duran_i_Lleida'", 0.0025571557], ["b' Hip\\xc3\\xb3lito_Mej\\xc3\\xada'", 0.00230611], ["b' Al_Bano_Carrisi'", 0.0012167396]]]
# Immagine: Maurizio_Sarri_5_face_0.jpg
# Predizione del modello: ' Maurizio_Sarri'
# Etichetta corretta: Maurizio_Sarri
# OK
# -------------------------->
# 1/1 [==============================] - 0s 200ms/step
# [[["b' Francesca_Schiavone'", 0.97191525], ["b' Fr\\xc3\\xa9d\\xc3\\xa9rick_Bousquet'", 0.0027471967], ["b' Emma_Moffatt'", 0.0026017278], ["b' Marta_Etura'", 0.00195786], ["b' Carla_Rebecchi'", 0.0017385078]]]
# Immagine: Francesca_Schiavone_9_face_0.jpg
# Predizione del modello: ' Francesca_Schiavone'
# Etichetta corretta: Francesca_Schiavone
# OK
# -------------------------->
# 1/1 [==============================] - 0s 211ms/step
# [[["b' Marko_Bulat'", 0.3606943], ["b' Svetislav_Pe\\xc5\\xa1i\\xc4\\x87'", 0.033106476], ["b' Jacob_Hoggard'", 0.031303477], ["b' Robert_Downey_Jr.'", 0.028395407], ["b' Robert_Turcescu'", 0.024007732]]]
# Immagine: Tony_Montana_9_face_0.jpg
# Predizione del modello: ' Marko_Bulat'
# Etichetta corretta: Tony_Montana
# -------------------------->
# 1/1 [==============================] - 0s 192ms/step
# [[["b' Craig_Bellamy'", 0.11057235], ["b' Ben_Mee'", 0.047478724], ["b' Marcos_Mondaini'", 0.032073], ["b' Emanuele_Giaccherini'", 0.029632788], ["b' Bruno_Martins_Indi'", 0.023100497]]]
# Immagine: Emanuele_Giaccherini_2_face_0.jpg
# Predizione del modello: ' Craig_Bellamy'
# Etichetta corretta: Emanuele_Giaccherini
# -------------------------->
# 1/1 [==============================] - 0s 192ms/step
# [[["b' David_Beckham'", 0.8898332], ["b' Nikolay_Baskov'", 0.03426573], ["b' Kayky_Brito'", 0.0075670914], ["b' Jesse_Lee_Soffer'", 0.0050026774], ["b' Scott_Eastwood'", 0.002782124]]]
# Immagine: David_Beckham_5_face_0.jpg
# Predizione del modello: ' David_Beckham'
# Etichetta corretta: David_Beckham
# OK
# -------------------------->
# 1/1 [==============================] - 0s 199ms/step
# [[["b' Fernando_Llorente'", 0.99153465], ["b' Chris_Judd'", 0.0018602918], ["b' G\\xc3\\xb6khan_Keser'", 0.001085407], ["b' Shraddha_Das'", 0.00042332613], ["b' Jos\\xc3\\xa9_Callej\\xc3\\xb3n'", 0.00023703839]]]
# Immagine: Fernando_Llorente_4_face_0.jpg
# Predizione del modello: ' Fernando_Llorente'
# Etichetta corretta: Fernando_Llorente
# OK
# -------------------------->
# 1/1 [==============================] - 0s 198ms/step
# [[["b' Samantha_Cristoforetti'", 0.994966], ["b' Malena_Alterio'", 0.0004123732], ["b' Birgitta_Ohlsson'", 0.00037147597], ["b' Irena_Santor'", 0.00011476784], ["b' Lilli_Gruber'", 0.00011458137]]]
# Immagine: Samantha_Cristoforetti_3_face_0.jpg
# Predizione del modello: ' Samantha_Cristoforetti'
# Etichetta corretta: Samantha_Cristoforetti
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Christopher_Nolan'", 0.972681], ["b' Claus_Elming'", 0.008871128], ["b' Charlie_Hunnam'", 0.001367573], ["b' Richard_Sul\\xc3\\xadk'", 0.0010563714], ["b' Mark_Robins'", 0.00097142527]]]
# Immagine: Christopher_Nolan_8_face_0.jpg
# Predizione del modello: ' Christopher_Nolan'
# Etichetta corretta: Christopher_Nolan
# OK
# -------------------------->
# 1/1 [==============================] - 0s 191ms/step
# [[["b' Valentina_Vezzali'", 0.9862221], ["b' C\\xc3\\xa9cilia_Attias'", 0.00051890564], ["b' Lillete_Dubey'", 0.00040192905], ["b' Esther_Schweins'", 0.00038110645], ["b' Liz_Phair'", 0.00036164612]]]
# Immagine: Valentina_Vezzali_4_face_0.jpg
# Predizione del modello: ' Valentina_Vezzali'
# Etichetta corretta: Valentina_Vezzali
# OK
# -------------------------->
# 1/1 [==============================] - 0s 194ms/step
# [[["b' Queen_Silvia_of_Sweden'", 0.92594725], ["b' Penelope_Wilton'", 0.011108749], ["b' Sylvie_Joly'", 0.00933165], ["b' Evelin_Ilves'", 0.0045429063], ["b' Ornella_Vanoni'", 0.003185036]]]
# Immagine: Queen_Silvia_of_Sweden_3_face_0.jpg
# Predizione del modello: ' Queen_Silvia_of_Sweden'
# Etichetta corretta: Queen_Silvia_of_Sweden
# OK
# -------------------------->
# 1/1 [==============================] - 0s 197ms/step
# [[["b' Susana_Werner'", 0.1628483], ["b' Gerit_Kling'", 0.11408851], ["b' Ayda_Field'", 0.07617936], ["b' Vanesa_Romero'", 0.04156881], ["b' Carmit_Bachar'", 0.022245428]]]
# Immagine: Micaela_Ramazzotti_7_face_0.jpg
# Predizione del modello: ' Susana_Werner'
# Etichetta corretta: Micaela_Ramazzotti
# -------------------------->
# 1/1 [==============================] - 0s 208ms/step
# [[["b' Quentin_L._Cook'", 0.1374221], ["b' Guus_Hiddink'", 0.052421656], ["b' Theo_Zwanziger'", 0.027359128], ["b' Deniz_Baykal'", 0.022082014], ["b' Ewald_Lienen'", 0.02198026]]]
# Immagine: Matthew_Perry_9_face_0.jpg
# Predizione del modello: ' Quentin_L._Cook'
# Etichetta corretta: Matthew_Perry
# -------------------------->
# 1/1 [==============================] - 0s 205ms/step
# [[["b' Marco_Fantini'", 0.55255127], ["b' Josh_Hartnett'", 0.06014266], ["b' Marcelo_Tinelli'", 0.023099681], ["b' Juli\\xc3\\xa1n_Gil'", 0.021613644], ["b' Ryan_Peake'", 0.017033627]]]
# Immagine: Marco_Fantini_1_face_0.jpg
# Predizione del modello: ' Marco_Fantini'
# Etichetta corretta: Marco_Fantini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 318ms/step
# [[["b' Vasco_Rossi'", 0.98938304], ["b' Kevin_Costner'", 0.0015977413], ["b' Rick_Gervais'", 0.0009758334], ["b' Steffen_Seibert'", 0.00082506513], ["b' Jason_Blum'", 0.00041931422]]]
# Immagine: Vasco_Rossi_9_face_0.jpg
# Predizione del modello: ' Vasco_Rossi'
# Etichetta corretta: Vasco_Rossi
# OK
# -------------------------->
# 1/1 [==============================] - 0s 311ms/step
# [[["b' Maurizio_Sarri'", 0.42373928], ["b' \\xc3\\x81ngel_Acebes'", 0.028345317], ["b' Angus_Deayton'", 0.02326074], ["b' Bruno_Solo'", 0.012066633], ["b' V\\xc3\\xadtor_Ba\\xc3\\xada'", 0.011200354]]]
# Immagine: Maurizio_Sarri_10_face_0.jpg
# Predizione del modello: ' Maurizio_Sarri'
# Etichetta corretta: Maurizio_Sarri
# OK
# -------------------------->
# 1/1 [==============================] - 0s 317ms/step
# [[["b' Matt_Damon'", 0.9173087], ["b' Paul_DiAnno'", 0.0068641156], ["b' Wayne_Boyd'", 0.0019861152], ["b' Guillaume_de_Tonqu\\xc3\\xa9dec'", 0.001973996], ["b' Jack_McGee'", 0.0016552942]]]
# Immagine: Matt_Damon_4_face_0.jpg
# Predizione del modello: ' Matt_Damon'
# Etichetta corretta: Matt_Damon
# OK
# -------------------------->
# 1/1 [==============================] - 0s 317ms/step
# [[["b' Marco_Mengoni'", 0.7498756], ["b' Ezequiel_Lavezzi'", 0.06290078], ["b' Alex_Ebert'", 0.023229364], ["b' Potito_Starace'", 0.018582959], ["b' Borja_Valero'", 0.010883294]]]
# Immagine: Marco_Mengoni_9_face_0.jpg
# Predizione del modello: ' Marco_Mengoni'
# Etichetta corretta: Marco_Mengoni
# OK
# -------------------------->
# 1/1 [==============================] - 0s 305ms/step
# [[["b' Engin_Altan_D\\xc3\\xbczyatan'", 0.14971165], ["b' Antonio_Orozco'", 0.13388401], ["b' Avraham_Fried'", 0.02687216], ["b' U\\xc4\\x9fur_T\\xc3\\xbct\\xc3\\xbcneker'", 0.019582799], ["b' Cal_Clutterbuck'", 0.018411722]]]
# Immagine: Luca_Argentero_5_face_0.jpg
# Predizione del modello: ' Engin_Altan_D\xc3\xbczyatan'
# Etichetta corretta: Luca_Argentero
# -------------------------->
# 1/1 [==============================] - 0s 326ms/step
# [[["b' Zendaya'", 0.95421576], ["b' Denise_Laurel'", 0.013773427], ["b' Andien'", 0.002312122], ["b' Vashtie_Kola'", 0.002030674], ["b' Krisdayanti'", 0.0012657329]]]
# Immagine: Zendaya_2_face_0.jpg
# Predizione del modello: ' Zendaya'
# Etichetta corretta: Zendaya
# OK
# -------------------------->
# 1/1 [==============================] - 0s 316ms/step
# [[["b' Enrico_Letta'", 0.9348177], ["b' Algirdas_\\xc5\\xa0emeta'", 0.0151174], ["b' Hank_Green'", 0.0031240494], ["b' Tico_Torres'", 0.0021393646], ["b' Joe_Oliver'", 0.0020090996]]]
# Immagine: Enrico_Letta_2_face_0.jpg
# Predizione del modello: ' Enrico_Letta'
# Etichetta corretta: Enrico_Letta
# OK
# -------------------------->
# 1/1 [==============================] - 0s 324ms/step
# [[["b' Jake_Weber'", 0.10204283], ["b' Robert_Downey_Jr.'", 0.037897136], ["b' Jorge_Aravena'", 0.032393396], ["b' Marko_Bulat'", 0.02684891], ["b' Tim_Roth'", 0.025960516]]]
# Immagine: Tony_Montana_4_face_0.jpg
# Predizione del modello: ' Jake_Weber'
# Etichetta corretta: Tony_Montana
# -------------------------->
# 1/1 [==============================] - 0s 329ms/step
# [[["b' Gennaro_Gattuso'", 0.25666833], ["b' Ismail_Haniyeh'", 0.040702526], ["b' Jayasurya'", 0.03902214], ["b' Hassan_Nasrallah'", 0.030606374], ["b' Rupert_Stadler'", 0.029042851]]]
# Immagine: Gennaro_Gattuso_8_face_0.jpg
# Predizione del modello: ' Gennaro_Gattuso'
# Etichetta corretta: Gennaro_Gattuso
# OK
# -------------------------->
# 1/1 [==============================] - 0s 384ms/step
# [[["b' Brad_Pitt'", 0.8654819], ["b' Nigel_John_Taylor'", 0.015597211], ["b' Rob_Lowe'", 0.013133129], ["b' Chad_Lowe'", 0.009940718], ["b' Bill_Rancic'", 0.0034553453]]]
# Immagine: Brad_Pitt_2_face_0.jpg
# Predizione del modello: ' Brad_Pitt'
# Etichetta corretta: Brad_Pitt
# OK
# -------------------------->
# 1/1 [==============================] - 0s 312ms/step
# [[["b' Robert_Pattison'", 0.9865726], ["b' Tom_Felton'", 0.0009197959], ["b' Charlie_Simpson'", 0.0007019441], ["b' River_Viiperi'", 0.00045634032], ["b' Valerio_Scanu'", 0.00043777138]]]
# Immagine: Robert_Pattison_1_face_0.jpg
# Predizione del modello: ' Robert_Pattison'
# Etichetta corretta: Robert_Pattison
# OK
# -------------------------->
# 1/1 [==============================] - 0s 190ms/step
# [[["b' Gerry_Scotti'", 0.99603313], ["b' Ehud_Barak'", 0.0022539746], ["b' Alessandro_Profumo'", 6.6845314e-05], ["b' Miguel_Lifschitz'", 6.4768865e-05], ["b' Dorival_J\\xc3\\xbanior'", 5.665702e-05]]]
# Immagine: Gerry_Scotti_6_face_0.jpg
# Predizione del modello: ' Gerry_Scotti'
# Etichetta corretta: Gerry_Scotti
# OK
# -------------------------->
# 1/1 [==============================] - 0s 201ms/step
# [[["b' Joaquin_Phoenix'", 0.958867], ["b' Goran_Vi\\xc5\\xa1nji\\xc4\\x87'", 0.0022537974], ["b' Erom_Cordeiro'", 0.0015798577], ["b' Jaz_Coleman'", 0.001255008], ["b' Claude_Barzotti'", 0.0011288789]]]
# Immagine: Joaquin_Phoenix_7_face_0.jpg
# Predizione del modello: ' Joaquin_Phoenix'
# Etichetta corretta: Joaquin_Phoenix
# OK
# -------------------------->
# 1/1 [==============================] - 0s 194ms/step
# [[["b' Tiziano_Ferro'", 0.99716586], ["b' Bar\\xc4\\xb1\\xc5\\x9f_Akarsu'", 0.00021263701], ["b' Daniel_H\\xc5\\xaflka'", 0.00014148396], ["b' V\\xc3\\xadtor_Ba\\xc3\\xada'", 9.283896e-05], ["b' Tom_Dwan'", 7.635917e-05]]]
# Immagine: Tiziano_Ferro_1_face_0.jpg
# Predizione del modello: ' Tiziano_Ferro'
# Etichetta corretta: Tiziano_Ferro
# OK
# -------------------------->
# 1/1 [==============================] - 0s 219ms/step
# [[["b' Marco_Carta'", 0.9965546], ["b' Clint_Mauro'", 0.00029815672], ["b' Paul_DiGiovanni'", 0.0002388035], ["b' Taylor_York'", 0.00010646873], ["b' Carlos_Sainz_Jr.'", 0.000103176106]]]
# Immagine: Marco_Carta_1_face_0.jpg
# Predizione del modello: ' Marco_Carta'
# Etichetta corretta: Marco_Carta
# OK
# -------------------------->
# 1/1 [==============================] - 0s 206ms/step
# [[["b' Thierry_Henry'", 0.8657814], ["b' Jos\\xc3\\xa9_Aldo'", 0.01816164], ["b' Gary_Sheffield'", 0.012948026], ["b' Matt_Kemp'", 0.011698693], ["b' Khalid_El-Amin'", 0.00448507]]]
# Immagine: Thierry_Henry_6_face_0.jpg
# Predizione del modello: ' Thierry_Henry'
# Etichetta corretta: Thierry_Henry
# OK
# -------------------------->
# 1/1 [==============================] - 0s 190ms/step
# [[["b' Arturo_Brachetti'", 0.10174852], ["b' Gustavo_Matosas'", 0.09870216], ["b' Bernhard_Langer'", 0.015889976], ["b' Charlie_Beck'", 0.013750003], ["b' Fran\\xc3\\xa7ois_Bayrou'", 0.013041564]]]
# Immagine: Luca_Parmitano_3_face_0.jpg
# Predizione del modello: ' Arturo_Brachetti'
# Etichetta corretta: Luca_Parmitano
# -------------------------->
# 1/1 [==============================] - 0s 188ms/step
# [[["b' Miriam_Leone'", 0.99727935], ["b' Pegah_Ahangarani'", 0.00060602516], ["b' Merve_Bolu\\xc4\\x9fur'", 0.000112223934], ["b' Lavinia_Longhi'", 9.784864e-05], ["b' Valeria_Solarino'", 9.2984046e-05]]]
# Immagine: Miriam_Leone_10_face_0.jpg
# Predizione del modello: ' Miriam_Leone'
# Etichetta corretta: Miriam_Leone
# OK
# -------------------------->
# 1/1 [==============================] - 0s 189ms/step
# [[["b' Matteo_Renzi'", 0.99765956], ["b' R\\xc3\\xa9mi_Garde'", 0.0011873136], ["b' Scott_Parker'", 0.00010254261], ["b' Pavel_B\\xc3\\xa9m'", 5.935045e-05], ["b' Ivan_Miklo\\xc5\\xa1'", 5.5669207e-05]]]
# Immagine: Matteo_Renzi_1_face_0.jpg
# Predizione del modello: ' Matteo_Renzi'
# Etichetta corretta: Matteo_Renzi
# OK
# -------------------------->
# 1/1 [==============================] - 0s 186ms/step
# [[["b' Sophia_Loren'", 0.96885586], ["b' Natalie_Imbruglia'", 0.0055400725], ["b' Catherine_Schell'", 0.0012463707], ["b' Phoebe_Price'", 0.0010814507], ["b' Ornella_Muti'", 0.00095515634]]]
# Immagine: Sophia_Loren_8_face_0.jpg
# Predizione del modello: ' Sophia_Loren'
# Etichetta corretta: Sophia_Loren
# OK
# -------------------------->
# 1/1 [==============================] - 0s 208ms/step
# [[["b' Alexandra_Socha'", 0.27919772], ["b' Tallulah_Belle_Willis'", 0.06676449], ["b' Toby_Hemingway'", 0.030183448], ["b' Nico_Rosberg'", 0.027424453], ["b' Damian_Charles_Hurley'", 0.020653738]]]
# Immagine: Leonardo_DiCaprio_9_face_0.jpg
# Predizione del modello: ' Alexandra_Socha'
# Etichetta corretta: Leonardo_DiCaprio
# -------------------------->
# 1/1 [==============================] - 0s 201ms/step
# [[["b' Luisana_Lopilato'", 0.99093306], ["b' Kelsey_Chow'", 0.0007270103], ["b' Jessica_Origliasso'", 0.00028910808], ["b' Luana_Piovani'", 0.00028076768], ["b' Laura_Kirkpatrick'", 0.00025903794]]]
# Immagine: Luisana_Lopilato_7_face_0.jpg
# Predizione del modello: ' Luisana_Lopilato'
# Etichetta corretta: Luisana_Lopilato
# OK
# -------------------------->
# 1/1 [==============================] - 0s 191ms/step
# [[["b' Mike_Tyson'", 0.8974481], ["b' Larry_Holmes'", 0.042650536], ["b' Jimmy_Butler'", 0.0027552769], ["b' Ne-Yo'", 0.0025625196], ["b' Robert_Cray'", 0.0025509864]]]
# Immagine: Mike_Tyson_2_face_0.jpg
# Predizione del modello: ' Mike_Tyson'
# Etichetta corretta: Mike_Tyson
# OK
# -------------------------->
# 1/1 [==============================] - 0s 205ms/step
# [[["b' Paolo_Maldini'", 0.9993918], ["b' Dani_Mart\\xc3\\xadn'", 8.950803e-05], ["b' Jan_Wieczorkowski'", 4.49334e-05], ["b' Simon_Le_Bon'", 4.1999727e-05], ["b' Rafael_S\\xc3\\xb3bis'", 3.0878033e-05]]]
# Immagine: Paolo_Maldini_10_face_0.jpg
# Predizione del modello: ' Paolo_Maldini'
# Etichetta corretta: Paolo_Maldini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Sophia_Loren'", 0.99268275], ["b' Linda_Evangelista'", 0.0011432557], ["b' Adelina_Ismajli'", 0.0010731826], ["b' Joana_Benedek'", 0.00084617763], ["b' Ornella_Muti'", 0.0004152422]]]
# Immagine: Sophia_Loren_5_face_0.jpg
# Predizione del modello: ' Sophia_Loren'
# Etichetta corretta: Sophia_Loren
# OK
# -------------------------->
# 1/1 [==============================] - 0s 190ms/step
# [[["b' Gennaro_Gattuso'", 0.9959864], ["b' Rapha\\xc3\\xabl_Personnaz'", 0.00064845645], ["b' Jos\\xc3\\xa9_Mar\\xc3\\xada_Torre'", 0.00020624587], ["b' Fatih_Tekke'", 0.00014969203], ["b' Dani_Mart\\xc3\\xadn'", 0.00011707528]]]
# Immagine: Gennaro_Gattuso_5_face_0.jpg
# Predizione del modello: ' Gennaro_Gattuso'
# Etichetta corretta: Gennaro_Gattuso
# OK
# -------------------------->
# 1/1 [==============================] - 0s 190ms/step
# [[["b' Elisabetta_Gregoraci'", 0.78505516], ["b' Rouwaida_Attieh'", 0.060099833], ["b' Yolanthe_Sneijder-Cabau'", 0.02720458], ["b' Federica_Nargi'", 0.020787444], ["b' Burcu_G\\xc3\\xbcne\\xc5\\x9f'", 0.015230597]]]
# Immagine: Elisabetta_Gregoraci_6_face_0.jpg
# Predizione del modello: ' Elisabetta_Gregoraci'
# Etichetta corretta: Elisabetta_Gregoraci
# OK
# -------------------------->
# 1/1 [==============================] - 0s 470ms/step
# [[["b' Christopher_Nolan'", 0.9669037], ["b' Xavier_Bettel'", 0.009846248], ["b' Koit_Toome'", 0.0070125647], ["b' Daniil_Trifonov'", 0.0008183696], ["b' \\xc3\\x96zg\\xc3\\xbcr_\\xc3\\x87evik'", 0.00061222597]]]
# Immagine: Christopher_Nolan_5_face_0.jpg
# Predizione del modello: ' Christopher_Nolan'
# Etichetta corretta: Christopher_Nolan
# OK
# -------------------------->
# 1/1 [==============================] - 0s 226ms/step
# [[["b' Matt_Damon'", 0.815551], ["b' Darren_Kennedy'", 0.028744597], ["b' Nick_Zano'", 0.022285305], ["b' Ronnie_Ortiz-Magro'", 0.019258019], ["b' Brian_Dietzen'", 0.013889827]]]
# Immagine: Matt_Damon_9_face_0.jpg
# Predizione del modello: ' Matt_Damon'
# Etichetta corretta: Matt_Damon
# OK
# -------------------------->
# 1/1 [==============================] - 0s 340ms/step
# [[["b' Malika_Ayane'", 0.5620469], ["b' Selma_Bajrami'", 0.13756695], ["b' Marta_S\\xc3\\xa1nchez'", 0.11517665], ["b' Indira_Vladi\\xc4\\x87'", 0.016794492], ["b' Victoria_Lopyreva'", 0.016453424]]]
# Immagine: Malika_Ayane_1_face_0.jpg
# Predizione del modello: ' Malika_Ayane'
# Etichetta corretta: Malika_Ayane
# OK
# -------------------------->
# 1/1 [==============================] - 0s 189ms/step
# [[["b' Roger_Federer'", 0.98162055], ["b' Graham_Zusi'", 0.0029422229], ["b' Mauricio_Islas'", 0.0012600248], ["b' Jorge_Luis_Pila'", 0.00097303116], ["b' Arbaaz_Khan'", 0.000554112]]]
# Immagine: Roger_Federer_1_face_0.jpg
# Predizione del modello: ' Roger_Federer'
# Etichetta corretta: Roger_Federer
# OK
# -------------------------->
# 1/1 [==============================] - 0s 189ms/step
# [[["b' Fernando_Llorente'", 0.97426933], ["b' Mirko_Vu\\xc4\\x8dini\\xc4\\x87'", 0.011739755], ["b' Lorik_Cana'", 0.0031675233], ["b' Chris_Judd'", 0.0015293612], ["b' Serdar_Kesimal'", 0.0004214195]]]
# Immagine: Fernando_Llorente_9_face_0.jpg
# Predizione del modello: ' Fernando_Llorente'
# Etichetta corretta: Fernando_Llorente
# OK
# -------------------------->
# 1/1 [==============================] - 0s 197ms/step
# [[["b' Riccardo_Fogli'", 0.4206096], ["b' Krzysztof_Ho\\xc5\\x82owczyc'", 0.07683978], ["b' Jon-Erik_Hexum'", 0.040172663], ["b' Jimmy_Stewart'", 0.024997877], ["b' Johan_Bruyneel'", 0.022401158]]]
# Immagine: Luke_Hemsworth_7_face_0.jpg
# Predizione del modello: ' Riccardo_Fogli'
# Etichetta corretta: Luke_Hemsworth
# -------------------------->
# 1/1 [==============================] - 0s 187ms/step
# [[["b' Willa_Holland'", 0.96962893], ["b' Summer_Altice'", 0.0019215348], ["b' Kristen_Alderson'", 0.0016815335], ["b' Shelley_Hennig'", 0.0008735802], ["b' Lisa_LoCicero'", 0.00084712665]]]
# Immagine: Willa_Holland_1_face_0.jpg
# Predizione del modello: ' Willa_Holland'
# Etichetta corretta: Willa_Holland
# OK
# -------------------------->
# 1/1 [==============================] - 0s 193ms/step
# [[["b' Giorgia_Meloni'", 0.7320581], ["b' Sarah_Cawood'", 0.030320255], ["b' Natalie_Cassidy'", 0.02486996], ["b' Natalie_Appleton'", 0.013988713], ["b' Anne-Sophie_Lapix'", 0.008263232]]]
# Immagine: Giorgia_Meloni_5_face_0.jpg
# Predizione del modello: ' Giorgia_Meloni'
# Etichetta corretta: Giorgia_Meloni
# OK
# -------------------------->
# 1/1 [==============================] - 0s 235ms/step
# [[["b' Edoardo_Leo'", 0.999696], ["b' Mart\\xc3\\xadn_Karpan'", 5.3974727e-05], ["b' Vedran_\\xc4\\x86orluka'", 2.275139e-05], ["b' Serdar_Kesimal'", 1.169283e-05], ["b' Pawe\\xc5\\x82_Del\\xc4\\x85g'", 1.1678788e-05]]]
# Immagine: Edoardo_Leo_4_face_0.jpg
# Predizione del modello: ' Edoardo_Leo'
# Etichetta corretta: Edoardo_Leo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 333ms/step
# [[["b' Philipp_Lahm'", 0.9946976], ["b' Gonzalo_Fierro'", 0.0018640789], ["b' Bu\\xc4\\x9fra_G\\xc3\\xbclsoy'", 0.00020287649], ["b' Gus_Hansen'", 0.00016142316], ["b' Esteban_Paredes'", 9.315631e-05]]]
# Immagine: Philipp_Lahm_3_face_0.jpg
# Predizione del modello: ' Philipp_Lahm'
# Etichetta corretta: Philipp_Lahm
# OK
# -------------------------->
# 1/1 [==============================] - 0s 312ms/step
# [[["b' Rita_Dalla_Chiesa'", 0.9955056], ["b' LeAnn_Rimes'", 0.0003121554], ["b' Patrizia_Pellegrino'", 0.0001823972], ["b' Chelsy_Davy'", 0.00016125213], ["b' Francesca_Lo_Schiavo'", 0.00013295645]]]
# Immagine: Rita_Dalla_Chiesa_8_face_0.jpg
# Predizione del modello: ' Rita_Dalla_Chiesa'
# Etichetta corretta: Rita_Dalla_Chiesa
# OK
# -------------------------->
# 1/1 [==============================] - 0s 321ms/step
# [[["b' Michael_Jackson'", 0.9838021], ["b' La_Toya_Jackson'", 0.010152626], ["b' Halle_Berry'", 0.00053075503], ["b' Mietta'", 0.0003892779], ["b' Shym'", 0.00027090404]]]
# Immagine: Michael_Jackson_4_face_0.jpg
# Predizione del modello: ' Michael_Jackson'
# Etichetta corretta: Michael_Jackson
# OK
# -------------------------->
# 1/1 [==============================] - 0s 324ms/step
# [[["b' Elisabetta_Gregoraci'", 0.94916207], ["b' Rouwaida_Attieh'", 0.0026419563], ["b' Liane_Foly'", 0.0020960514], ["b' Carla_Ortiz'", 0.0020118658], ["b' Burcu_G\\xc3\\xbcne\\xc5\\x9f'", 0.0013547232]]]
# Immagine: Elisabetta_Gregoraci_10_face_0.jpg
# Predizione del modello: ' Elisabetta_Gregoraci'
# Etichetta corretta: Elisabetta_Gregoraci
# OK
# -------------------------->
# 1/1 [==============================] - 0s 315ms/step
# [[["b' Gerard_Tubier'", 0.35745877], ["b' Luca_Toni'", 0.30723935], ["b' Thomas_Dutronc'", 0.02159909], ["b' Vincent_Regan'", 0.017689578], ["b' Jordi_Moll\\xc3\\xa0'", 0.015493176]]]
# Immagine: Luca_Toni_8_face_0.jpg
# Predizione del modello: ' Gerard_Tubier'
# Etichetta corretta: Luca_Toni
# -------------------------->
# 1/1 [==============================] - 0s 312ms/step
# [[["b' Ursula_von_der_Leyen'", 0.99510163], ["b' Bettina_Cramer'", 0.0014151279], ["b' Lisa_Stansfield'", 0.00022825201], ["b' Gudrun_Landgrebe'", 9.080589e-05], ["b' Siv_Jensen'", 8.4601495e-05]]]
# Immagine: Ursula_von_der_Leyen_4_face_0.jpg
# Predizione del modello: ' Ursula_von_der_Leyen'
# Etichetta corretta: Ursula_von_der_Leyen
# OK
# -------------------------->
# 1/1 [==============================] - 0s 309ms/step
# [[["b' Sushil_Koirala'", 0.5117536], ["b' Sushil_Kumar_Modi'", 0.06640459], ["b' Ismail_Haniyeh'", 0.033077694], ["b' Sergio_Cofferati'", 0.025540018], ["b' Ali_Akbar_Salehi'", 0.024172526]]]
# Immagine: Flavio_Briatore_1_face_0.jpg
# Predizione del modello: ' Sushil_Koirala'
# Etichetta corretta: Flavio_Briatore
# -------------------------->
# 1/1 [==============================] - 0s 334ms/step
# [[["b' Antonio_Cassano'", 0.70636535], ["b' William_Porterfield'", 0.011028352], ["b' Michal_B\\xc3\\xadlek'", 0.0071778293], ["b' Steven_Motlop'", 0.0069182524], ["b' Kamil_Drygas'", 0.0043712775]]]
# Immagine: Antonio_Cassano_10_face_0.jpg
# Predizione del modello: ' Antonio_Cassano'
# Etichetta corretta: Antonio_Cassano
# OK
# -------------------------->
# 1/1 [==============================] - 0s 295ms/step
# [[["b' Robert_Downey_Jr.'", 0.99944], ["b' Jamie_Hince'", 4.0612475e-05], ["b' Manu_Payet'", 3.7671572e-05], ["b' Demi\\xc3\\xa1n_Bichir'", 2.0368527e-05], ["b' Rafael_Novoa'", 1.8180977e-05]]]
# Immagine: Robert_Downey_Jr_2_face_0.jpg
# Predizione del modello: ' Robert_Downey_Jr.'
# Etichetta corretta: Robert_Downey_Jr
# OK
# -------------------------->
# 1/1 [==============================] - 0s 328ms/step
# [[["b' Lorenzo_Insigne'", 0.93536586], ["b' H\\xc3\\xa9lder_Postiga'", 0.006960448], ["b' Antonio_Nocerino'", 0.0050679883], ["b' Mattia_Destro'", 0.004199335], ["b' Miguel_Veloso'", 0.0030748493]]]
# Immagine: Lorenzo_Insigne_7_face_0.jpg
# Predizione del modello: ' Lorenzo_Insigne'
# Etichetta corretta: Lorenzo_Insigne
# OK
# -------------------------->
# 1/1 [==============================] - 0s 320ms/step
# [[["b' Gervinho'", 0.8949471], ["b' Kenwyne_Jones'", 0.0075775404], ["b' Travis_Scott'", 0.006820707], ["b' Emmanuel_Adebayor'", 0.0064068935], ["b' James_Dasaolu'", 0.005999395]]]
# Immagine: Gervinho_1_face_0.jpg
# Predizione del modello: ' Gervinho'
# Etichetta corretta: Gervinho
# OK
# -------------------------->
# 1/1 [==============================] - 0s 322ms/step
# [[["b' Lorella_Cuccarini'", 0.99832517], ["b' Sandrine_Corman'", 0.00052350113], ["b' Amy_Brenneman'", 7.385383e-05], ["b' Mich\\xc3\\xa8le_Torr'", 4.5244087e-05], ["b' Daisy_Fuentes'", 3.4620407e-05]]]
# Immagine: Lorella_Cuccarini_10_face_0.jpg
# Predizione del modello: ' Lorella_Cuccarini'
# Etichetta corretta: Lorella_Cuccarini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 193ms/step
# [[["b' Randy_Orton'", 0.8799581], ["b' Nikolai_Valuev'", 0.0040595033], ["b' Pat_Cash'", 0.003722487], ["b' Jeremy_Stephens'", 0.0033317124], ["b' Nico_H\\xc3\\xbclkenberg'", 0.0032110938]]]
# Immagine: Randy_Orton_2_face_0.jpg
# Predizione del modello: ' Randy_Orton'
# Etichetta corretta: Randy_Orton
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Geoffrey_Kondogbia'", 0.99271387], ["b' Ga\\xc3\\xabl_Kakuta'", 0.00051203725], ["b' Abou_Diaby'", 0.0004734103], ["b' Nelson_\\xc3\\x89vora'", 0.0003603725], ["b' Rio_Mavuba'", 0.00035974925]]]
# Immagine: Geoffrey_Kondogbia_8_face_0.jpg
# Predizione del modello: ' Geoffrey_Kondogbia'
# Etichetta corretta: Geoffrey_Kondogbia
# OK
# -------------------------->
# 1/1 [==============================] - 0s 192ms/step
# [[["b' Travis_Scott'", 0.91419095], ["b' Moussa_Dadis_Camara'", 0.011626309], ["b' Ramires'", 0.0104853995], ["b' Max_Gradel'", 0.008097646], ["b' Bakary_Sako'", 0.0058507323]]]
# Immagine: Travis_Scott_8_face_0.jpg
# Predizione del modello: ' Travis_Scott'
# Etichetta corretta: Travis_Scott
# OK
# -------------------------->
# 1/1 [==============================] - 0s 187ms/step
# [[["b' Emanuele_Giaccherini'", 0.9921119], ["b' Ben_Mee'", 0.0017975973], ["b' Kevin_Mirallas'", 0.001023132], ["b' Reto_Ziegler'", 0.0005900103], ["b' Germ\\xc3\\xa1n_Denis'", 0.00040171374]]]
# Immagine: Emanuele_Giaccherini_7_face_0.jpg
# Predizione del modello: ' Emanuele_Giaccherini'
# Etichetta corretta: Emanuele_Giaccherini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 199ms/step
# [[["b' Gigi_DAlessio'", 0.99684167], ["b' Udo_Dirkschneider'", 0.00021146087], ["b' Mikael_Granlund'", 0.0001481244], ["b' Joseph_Muscat'", 0.0001236538], ["b' Louie_Anderson'", 0.00010564663]]]
# Immagine: Gigi_DAlessio_5_face_0.jpg
# Predizione del modello: ' Gigi_DAlessio'
# Etichetta corretta: Gigi_DAlessio
# OK
# -------------------------->
# 1/1 [==============================] - 0s 191ms/step
# [[["b' Willa_Holland'", 0.9903791], ["b' Edda_Magnason'", 0.0009308219], ["b' Alessandra_Mastronardi'", 0.0008298425], ["b' Bobbi_Sue_Luther'", 0.0004391238], ["b' Fabiula_Nascimento'", 0.00019971149]]]
# Immagine: Willa_Holland_4_face_0.jpg
# Predizione del modello: ' Willa_Holland'
# Etichetta corretta: Willa_Holland
# OK
# -------------------------->
# 1/1 [==============================] - 0s 188ms/step
# [[["b' Max_Pezzali'", 0.9923774], ["b' Ross_Antony'", 0.0005358268], ["b' Robin_S\\xc3\\xb6derling'", 0.0003372373], ["b' Derren_Brown'", 0.0002861378], ["b' Michael_Franti'", 0.00022544384]]]
# Immagine: Max_Pezzali_8_face_0.jpg
# Predizione del modello: ' Max_Pezzali'
# Etichetta corretta: Max_Pezzali
# OK
# -------------------------->
# 1/1 [==============================] - 0s 188ms/step
# [[["b' Michael_Jackson'", 0.9689698], ["b' Mietta'", 0.0069514015], ["b' Fernanda_Brand\\xc3\\xa3o'", 0.0018751242], ["b' Gina_Parody'", 0.0012499564], ["b' Vanessa_da_Mata'", 0.0010545211]]]
# Immagine: Michael_Jackson_1_face_0.jpg
# Predizione del modello: ' Michael_Jackson'
# Etichetta corretta: Michael_Jackson
# OK
# -------------------------->
# 1/1 [==============================] - 0s 180ms/step
# [[["b' Andrea_Pirlo'", 0.99142855], ["b' Gines_Garcia_Millan'", 0.001752554], ["b' Bruno_Bichir'", 0.0007038589], ["b' Henri_Leconte'", 0.0006165752], ["b' Serdar_Kesimal'", 0.00029033268]]]
# Immagine: Andrea_Pirlo_5_face_0.jpg
# Predizione del modello: ' Andrea_Pirlo'
# Etichetta corretta: Andrea_Pirlo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 186ms/step
# [[["b' Cristiano_Ronaldo'", 0.92052317], ["b' Dominick_Cruz'", 0.0045702723], ["b' Francisco_Palencia'", 0.0023950362], ["b' Gonzalo_Fierro'", 0.0023150446], ["b' Esteban_Paredes'", 0.0019377023]]]
# Immagine: Cristiano_Ronaldo_3_face_0.jpg
# Predizione del modello: ' Cristiano_Ronaldo'
# Etichetta corretta: Cristiano_Ronaldo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 199ms/step
# [[["b' Ryan_Gosling'", 0.9972089], ["b' Philippe_Cousteau'", 0.00025888355], ["b' Thomas_Dutronc'", 0.00016707783], ["b' Max_Riemelt'", 0.00012868254], ["b' James_Hinchcliffe'", 0.00011582307]]]
# Immagine: Ryan_Gosling_2_face_0.jpg
# Predizione del modello: ' Ryan_Gosling'
# Etichetta corretta: Ryan_Gosling
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Orlando_Bloom'", 0.65847075], ["b' Christopher_Masterson'", 0.03529466], ["b' Jason_Blum'", 0.026676588], ["b' Rick_Gervais'", 0.02087262], ["b' Filip_Bla\\xc5\\xbeek'", 0.010925489]]]
# Immagine: Orlando_Bloom_3_face_0.jpg
# Predizione del modello: ' Orlando_Bloom'
# Etichetta corretta: Orlando_Bloom
# OK
# -------------------------->
# 1/1 [==============================] - 0s 192ms/step
# [[["b' Maurizio_Sarri'", 0.66710764], ["b' Jos\\xc3\\xa9_Eduardo_Cardozo'", 0.021481926], ["b' \\xc3\\x81ngel_Acebes'", 0.01777424], ["b' Fernando_de_la_R\\xc3\\xbaa'", 0.015487924], ["b' Fran\\xc3\\xa7ois_Fillon'", 0.014894718]]]
# Immagine: Maurizio_Sarri_8_face_0.jpg
# Predizione del modello: ' Maurizio_Sarri'
# Etichetta corretta: Maurizio_Sarri
# OK
# -------------------------->
# 1/1 [==============================] - 0s 189ms/step
# [[["b' Paolo_Bonolis'", 0.9884544], ["b' Rupert_Stadler'", 0.0034937116], ["b' Jens_Stoltenberg'", 0.0020816594], ["b' Rainhard_Fendrich'", 0.0006056871], ["b' Mauricio_Funes'", 0.00024288685]]]
# Immagine: Paolo_Bonolis_2_face_0.jpg
# Predizione del modello: ' Paolo_Bonolis'
# Etichetta corretta: Paolo_Bonolis
# OK
# -------------------------->
# 1/1 [==============================] - 0s 192ms/step
# [[["b' Antonio_Cassano'", 0.9604813], ["b' Antonio_Mohamed'", 0.004097713], ["b' Jerzy_Brz\\xc4\\x99czek'", 0.0019181817], ["b' Leo_Varadkar'", 0.0011227627], ["b' Tony_Stewart'", 0.0010431638]]]
# Immagine: Antonio_Cassano_6_face_0.jpg
# Predizione del modello: ' Antonio_Cassano'
# Etichetta corretta: Antonio_Cassano
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Michael_B._Jordan'", 0.94457805], ["b' Stephen_Marley'", 0.0056450577], ["b' Dorlan_Pab\\xc3\\xb3n'", 0.0040505943], ["b' Mekhi_Phifer'", 0.0028891533], ["b' Ky-Mani_Marley'", 0.0018601067]]]
# Immagine: Michael_B._Jordan_3_face_0.jpg
# Predizione del modello: ' Michael_B._Jordan'
# Etichetta corretta: Michael_B._Jordan
# OK
# -------------------------->
# 1/1 [==============================] - 0s 196ms/step
# [[["b' Vladimir_Luxuria'", 0.86153585], ["b' Clara_Rojas'", 0.009058971], ["b' Hiam_Abbass'", 0.008552985], ["b' Candan_Er\\xc3\\xa7etin'", 0.0034612333], ["b' C\\xc3\\xa9cile_Duflot'", 0.0027827509]]]
# Immagine: Vladimir_Luxuria_5_face_0.jpg
# Predizione del modello: ' Vladimir_Luxuria'
# Etichetta corretta: Vladimir_Luxuria
# OK
# -------------------------->
# 1/1 [==============================] - 0s 213ms/step
# [[["b' Laura_Chiatti'", 0.99327457], ["b' Lyndsy_Fonseca'", 0.002658489], ["b' Thomas_Vermaelen'", 0.00017804619], ["b' Danielle_Cormack'", 0.00013694553], ["b' Laura_Kirkpatrick'", 0.00013452981]]]
# Immagine: Laura_Chiatti_4_face_0.jpg
# Predizione del modello: ' Laura_Chiatti'
# Etichetta corretta: Laura_Chiatti
# OK
# -------------------------->
# 1/1 [==============================] - 0s 190ms/step
# [[["b' \\xc4\\xb0lber_Ortayl\\xc4\\xb1'", 0.6033575], ["b' Russell_Crowe'", 0.12425601], ["b' S\\xc3\\xbcmer_Tilma\\xc3\\xa7'", 0.10413531], ["b' Karekin_II'", 0.036877036], ["b' Edo_Maajka'", 0.009681512]]]
# Immagine: Russell_Crowe_9_face_0.jpg
# Predizione del modello: ' \xc4\xb0lber_Ortayl\xc4\xb1'
# Etichetta corretta: Russell_Crowe
# -------------------------->
# 1/1 [==============================] - 0s 184ms/step
# [[["b' Matteo_Darmian'", 0.49725217], ["b' Mats_Hummels'", 0.025509434], ["b' Danko_Lazovi\\xc4\\x87'", 0.013917349], ["b' Gamal_Mubarak'", 0.012127674], ["b' \\xc3\\x81lvaro_Arbeloa'", 0.010045894]]]
# Immagine: Matteo_Darmian_5_face_0.jpg
# Predizione del modello: ' Matteo_Darmian'
# Etichetta corretta: Matteo_Darmian
# OK
# -------------------------->
# 1/1 [==============================] - 0s 223ms/step
# [[["b' Ursula_von_der_Leyen'", 0.9891579], ["b' Fiona_Phillips'", 0.0005715159], ["b' Hilde_Crevits'", 0.00046793607], ["b' Maureen_Lipman'", 0.00045885122], ["b' Gai_Waterhouse'", 0.0004542339]]]
# Immagine: Ursula_von_der_Leyen_1_face_0.jpg
# Predizione del modello: ' Ursula_von_der_Leyen'
# Etichetta corretta: Ursula_von_der_Leyen
# OK
# -------------------------->
# 1/1 [==============================] - 0s 199ms/step
# [[["b' Samuel_Etoo'", 0.9906156], ["b' Bershawn_Jackson'", 0.0004890678], ["b' Andre_Berto'", 0.00047840332], ["b' Joseph_Yobo'", 0.00044359235], ["b' May_Mahlangu'", 0.00039624432]]]
# Immagine: Samuel_Etoo_9_face_0.jpg
# Predizione del modello: ' Samuel_Etoo'
# Etichetta corretta: Samuel_Etoo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 187ms/step
# [[["b' Valentina_Vezzali'", 0.997156], ["b' Kate\\xc5\\x99ina_Bro\\xc5\\xbeov\\xc3\\xa1'", 0.00035003916], ["b' Liz_Phair'", 0.00022373084], ["b' Annika_Jankell'", 0.00017831067], ["b' Teryl_Rothery'", 0.0001781171]]]
# Immagine: Valentina_Vezzali_9_face_0.jpg
# Predizione del modello: ' Valentina_Vezzali'
# Etichetta corretta: Valentina_Vezzali
# OK
# -------------------------->
# 1/1 [==============================] - 0s 202ms/step
# [[["b' Vanessa_Incontrada'", 0.9946926], ["b' Elizabeth_Vargas'", 0.00093592686], ["b' Carolina_Ferraz'", 0.00037543528], ["b' Emma_Marcegaglia'", 0.00029088074], ["b' Aykut_Kocaman'", 0.00016255488]]]
# Immagine: Vanessa_Incontrada_3_face_0.jpg
# Predizione del modello: ' Vanessa_Incontrada'
# Etichetta corretta: Vanessa_Incontrada
# OK
# -------------------------->
# 1/1 [==============================] - 0s 189ms/step
# [[["b' Roberto_Bolle'", 0.7715064], ["b' Simon_Le_Bon'", 0.025075695], ["b' Jude_Law'", 0.0078887325], ["b' Roger_Donaldson'", 0.007508875], ["b' Christian_Campbell'", 0.006869751]]]
# Immagine: Roberto_Bolle_7_face_0.jpg
# Predizione del modello: ' Roberto_Bolle'
# Etichetta corretta: Roberto_Bolle
# OK
# -------------------------->
# 1/1 [==============================] - 0s 203ms/step
# [[["b' Francesca_Schiavone'", 0.99405944], ["b' Gonzalo_Fierro'", 0.00036165921], ["b' Emma_Moffatt'", 0.00030937124], ["b' Jon_Dahl_Tomasson'", 0.00030822714], ["b' Herschelle_Gibbs'", 0.00028715684]]]
# Immagine: Francesca_Schiavone_4_face_0.jpg
# Predizione del modello: ' Francesca_Schiavone'
# Etichetta corretta: Francesca_Schiavone
# OK
# -------------------------->
# 1/1 [==============================] - 0s 199ms/step
# [[["b' Paolo_Maldini'", 0.9992111], ["b' Antonio_Conte'", 0.0001088949], ["b' Rafael_S\\xc3\\xb3bis'", 8.8892266e-05], ["b' Senad_Luli\\xc4\\x87'", 2.4311226e-05], ["b' Roman_Polko'", 1.698363e-05]]]
# Immagine: Paolo_Maldini_9_face_0.jpg
# Predizione del modello: ' Paolo_Maldini'
# Etichetta corretta: Paolo_Maldini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 193ms/step
# [[["b' Vasco_Rossi'", 0.997866], ["b' Sia_Furler'", 0.00016832059], ["b' Emir_Had\\xc5\\xbeihafizbegovi\\xc4\\x87'", 0.00016714615], ["b' Laurence_Fishburne'", 4.6177847e-05], ["b' Ma\\xc5\\x82gorzata_Braunek'", 4.4220866e-05]]]
# Immagine: Vasco_Rossi_4_face_0.jpg
# Predizione del modello: ' Vasco_Rossi'
# Etichetta corretta: Vasco_Rossi
# OK
# -------------------------->
# 1/1 [==============================] - 0s 206ms/step
# [[["b' Ezio_Greggio'", 0.99788445], ["b' Dustin_Hoffman'", 0.00035922072], ["b' \\xc3\\x93scar_Tab\\xc3\\xa1rez'", 0.00024131755], ["b' Davy_Russell'", 0.00011098538], ["b' Lu\\xc3\\xads_Figo'", 8.056474e-05]]]
# Immagine: Ezio_Greggio_5_face_0.jpg
# Predizione del modello: ' Ezio_Greggio'
# Etichetta corretta: Ezio_Greggio
# OK
# -------------------------->
# 1/1 [==============================] - 0s 324ms/step
# [[["b' Ewald_Lienen'", 0.061971493], ["b' Alois_Hadamczik'", 0.050881892], ["b' Tobias_Moretti'", 0.043051954], ["b' Jean-Marie_Bigard'", 0.035624843], ["b' Vincent_Regan'", 0.021595683]]]
# Immagine: Matthew_Perry_4_face_0.jpg
# Predizione del modello: ' Ewald_Lienen'
# Etichetta corretta: Matthew_Perry
# -------------------------->
# 1/1 [==============================] - 0s 309ms/step
# [[["b' Tim_Cook'", 0.8160028], ["b' Marcelo_Buquet'", 0.05748981], ["b' Paul_Magnette'", 0.04303234], ["b' Eckart_von_Hirschhausen'", 0.013287098], ["b' Robert_Gant'", 0.01321237]]]
# Immagine: Tim_Cook_8_face_0.jpg
# Predizione del modello: ' Tim_Cook'
# Etichetta corretta: Tim_Cook
# OK
# -------------------------->
# 1/1 [==============================] - 0s 310ms/step
# [[["b' Ariana_Grande'", 0.29230392], ["b' Gong_Xinliang'", 0.07086875], ["b' Alie_Layus'", 0.025444422], ["b' Rina_Akiyama'", 0.01887806], ["b' Ruby_Lin'", 0.017588492]]]
# Immagine: Ariana_Grande_5_face_0.jpg
# Predizione del modello: ' Ariana_Grande'
# Etichetta corretta: Ariana_Grande
# OK
# -------------------------->
# 1/1 [==============================] - 0s 350ms/step
# [[["b' Ariana_Grande'", 0.1720187], ["b' Adrienne_Bailon'", 0.0630676], ["b' Holly_Golightly'", 0.04903734], ["b' Evgenia_Obraztsova'", 0.029468559], ["b' Vanessa_Peretti'", 0.02201179]]]
# Immagine: Ariana_Grande_10_face_0.jpg
# Predizione del modello: ' Ariana_Grande'
# Etichetta corretta: Ariana_Grande
# OK
# -------------------------->
# 1/1 [==============================] - 0s 370ms/step
# [[["b' Narendra_Modi'", 0.10336745], ["b' Anders_Osborne'", 0.09138454], ["b' Osman_Nuri_Topba\\xc5\\x9f'", 0.086872205], ["b' Sushil_Koirala'", 0.07474732], ["b' Karekin_II'", 0.061335072]]]
# Immagine: Flavio_Briatore_4_face_0.jpg
# Predizione del modello: ' Narendra_Modi'
# Etichetta corretta: Flavio_Briatore
# -------------------------->
# 1/1 [==============================] - 0s 448ms/step
# [[["b' Riccardo_Scamarcio'", 0.98030937], ["b' Felipe_Braun'", 0.00056393456], ["b' Geoff_Eigenmann'", 0.0004799173], ["b' Michel_Boujenah'", 0.00030526306], ["b' Jos\\xc3\\xa9_S\\xc3\\xb3crates'", 0.00026126477]]]
# Immagine: Riccardo_Scamarcio_9_face_0.jpg
# Predizione del modello: ' Riccardo_Scamarcio'
# Etichetta corretta: Riccardo_Scamarcio
# OK
# -------------------------->
# 1/1 [==============================] - 0s 416ms/step
# [[["b' Ronnie_Coleman'", 0.99034274], ["b' Titus_ONeil'", 0.0020127958], ["b' Terry_Crews'", 0.00078865], ["b' Abou_Diaby'", 0.0007517196], ["b' Hans_Sarpei'", 0.0004054805]]]
# Immagine: Ronnie_Coleman_9_face_0.jpg
# Predizione del modello: ' Ronnie_Coleman'
# Etichetta corretta: Ronnie_Coleman
# OK
# -------------------------->
# 1/1 [==============================] - 0s 367ms/step
# [[["b' Gervinho'", 0.8686709], ["b' Moussa_Sow'", 0.04384075], ["b' Kei_Kamara'", 0.015597307], ["b' Lilian_Thuram'", 0.0038364544], ["b' Bakary_Sako'", 0.0036296744]]]
# Immagine: Gervinho_4_face_0.jpg
# Predizione del modello: ' Gervinho'
# Etichetta corretta: Gervinho
# OK
# -------------------------->
# 1/1 [==============================] - 1s 567ms/step
# [[["b' Luciano_Spalletti'", 0.9953355], ["b' Ziya_Do\\xc4\\x9fan'", 0.0010574027], ["b' Robert_Maaskant'", 0.00023808618], ["b' Semih_Sayg\\xc4\\xb1ner'", 0.00023802034], ["b' Boyko_Borisov'", 0.00021509253]]]
# Immagine: Luciano_Spalletti_10_face_0.jpg
# Predizione del modello: ' Luciano_Spalletti'
# Etichetta corretta: Luciano_Spalletti
# OK
# -------------------------->
# 1/1 [==============================] - 0s 357ms/step
# [[["b' Massimo_Ranieri'", 0.9991456], ["b' Jean-Louis_Borloo'", 0.00010060959], ["b' Humberto_Gessinger'", 7.126312e-05], ["b' Darko_Rundek'", 4.844032e-05], ["b' Fr\\xc3\\xa9d\\xc3\\xa9ric_de_Saint-Sernin'", 3.5485962e-05]]]
# Immagine: Massimo_Ranieri_5_face_0.jpg
# Predizione del modello: ' Massimo_Ranieri'
# Etichetta corretta: Massimo_Ranieri
# OK
# -------------------------->
# 1/1 [==============================] - 0s 374ms/step
# [[["b' Samantha_Cristoforetti'", 0.9988777], ["b' Kari_Bremnes'", 9.360447e-05], ["b' Micheline_Calmy-Rey'", 7.5318596e-05], ["b' Mary_Portas'", 7.409851e-05], ["b' Christine_Lieberknecht'", 6.900717e-05]]]
# Immagine: Samantha_Cristoforetti_10_face_0.jpg
# Predizione del modello: ' Samantha_Cristoforetti'
# Etichetta corretta: Samantha_Cristoforetti
# OK
# -------------------------->
# 1/1 [==============================] - 0s 321ms/step
# [[["b' Fernando_Llorente'", 0.9893115], ["b' Jaime_Alguersuari'", 0.0010885026], ["b' H\\xc3\\xa5vard_Nordtveit'", 0.0003615229], ["b' Fernando_San_Emeterio'", 0.0002961944], ["b' Sebastian_Kehl'", 0.00028642185]]]
# Immagine: Fernando_Llorente_10_face_0.jpg
# Predizione del modello: ' Fernando_Llorente'
# Etichetta corretta: Fernando_Llorente
# OK
# -------------------------->
# 1/1 [==============================] - 0s 324ms/step
# [[["b' Edoardo_Leo'", 0.9984322], ["b' Juan_Garc\\xc3\\xada_Postigo'", 0.00013106769], ["b' Mart\\xc3\\xadn_Karpan'", 0.000119928685], ["b' Ricky_Paull_Goldin'", 9.65702e-05], ["b' Pawe\\xc5\\x82_Del\\xc4\\x85g'", 6.2894585e-05]]]
# Immagine: Edoardo_Leo_1_face_0.jpg
# Predizione del modello: ' Edoardo_Leo'
# Etichetta corretta: Edoardo_Leo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 217ms/step
# [[["b' Zendaya'", 0.9203808], ["b' Denise_Laurel'", 0.039335635], ["b' Andien'", 0.013477339], ["b' Jessy_Mendiola'", 0.002530318], ["b' Chrissie_Chau'", 0.001533845]]]
# Immagine: Zendaya_7_face_0.jpg
# Predizione del modello: ' Zendaya'
# Etichetta corretta: Zendaya
# OK
# -------------------------->
# 1/1 [==============================] - 0s 196ms/step
# [[["b' Enrico_Ruggeri'", 0.9891424], ["b' Andr\\xc3\\xa9s_Manuel_L\\xc3\\xb3pez_Obrador'", 0.0020339063], ["b' Diosdado_Cabello'", 0.0019356948], ["b' Dragan_\\xc5\\xa0utanovac'", 0.0006552022], ["b' Eugenio_Finardi'", 0.00023711324]]]
# Immagine: Enrico_Ruggeri_10_face_0.jpg
# Predizione del modello: ' Enrico_Ruggeri'
# Etichetta corretta: Enrico_Ruggeri
# OK
# -------------------------->
# 1/1 [==============================] - 0s 183ms/step
# [[["b' Maia_Mitchell'", 0.986725], ["b' MacKenzie_Mauzy'", 0.0026533594], ["b' Elianne_Smit'", 0.0017617194], ["b' Indiana_Evans'", 0.0009115211], ["b' Shelley_Hennig'", 0.0005801766]]]
# Immagine: Maia_Mitchell_9_face_0.jpg
# Predizione del modello: ' Maia_Mitchell'
# Etichetta corretta: Maia_Mitchell
# OK
# -------------------------->
# 1/1 [==============================] - 0s 188ms/step
# [[["b' Enrico_Letta'", 0.41559112], ["b' Massimo_Ranieri'", 0.12146985], ["b' Carlos_Arthur_Nuzman'", 0.06552182], ["b' Tico_Torres'", 0.03607237], ["b' Kai_Schumann'", 0.0318983]]]
# Immagine: Enrico_Letta_7_face_0.jpg
# Predizione del modello: ' Enrico_Letta'
# Etichetta corretta: Enrico_Letta
# OK
# -------------------------->
# 1/1 [==============================] - 0s 210ms/step
# [[["b' Matteo_Salvini'", 0.9967399], ["b' Tony_Stewart'", 0.00051865337], ["b' Boo_Weekley'", 0.00041584013], ["b' DJ_Khaled'", 0.00021833507], ["b' Andrzej_Piaseczny'", 0.00016287593]]]
# Immagine: Matteo_Salvini_9_face_0.jpg
# Predizione del modello: ' Matteo_Salvini'
# Etichetta corretta: Matteo_Salvini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 189ms/step
# [[["b' Olivier_Giroud'", 0.15593307], ["b' Lorenzo_Insigne'", 0.07987435], ["b' Maxi_Biancucchi'", 0.03127355], ["b' Serdar_Kesimal'", 0.026998542], ["b' Gerard_Piqu\\xc3\\xa9'", 0.020595457]]]
# Immagine: Lorenzo_Insigne_2_face_0.jpg
# Predizione del modello: ' Olivier_Giroud'
# Etichetta corretta: Lorenzo_Insigne
# -------------------------->
# 1/1 [==============================] - 0s 190ms/step
# [[["b' Jean-Pierre_Foucault'", 0.042066775], ["b' Llu\\xc3\\xads_Llach'", 0.026372636], ["b' Tim_Roth'", 0.026265558], ["b' Thomas_Dutronc'", 0.025655907], ["b' Jake_Weber'", 0.024685238]]]
# Immagine: Tony_Montana_1_face_0.jpg
# Predizione del modello: ' Jean-Pierre_Foucault'
# Etichetta corretta: Tony_Montana
# -------------------------->
# 1/1 [==============================] - 0s 194ms/step
# [[["b' Christian_Berkel'", 0.15868501], ["b' Heiner_Lauterbach'", 0.13071197], ["b' Daniel_Landa'", 0.06638409], ["b' Arturo_Brachetti'", 0.05128767], ["b' Fabien_Barthez'", 0.047274556]]]
# Immagine: Luca_Parmitano_6_face_0.jpg
# Predizione del modello: ' Christian_Berkel'
# Etichetta corretta: Luca_Parmitano
# -------------------------->
# 1/1 [==============================] - 0s 187ms/step
# [[["b' Robert_Downey_Jr.'", 0.9990847], ["b' Carlos_Bardem'", 0.00010717305], ["b' Jan_Josef_Liefers'", 5.3672782e-05], ["b' Steve_Coogan'", 2.7039689e-05], ["b' Sergio_Dalma'", 2.1319018e-05]]]
# Immagine: Robert_Downey_Jr_7_face_0.jpg
# Predizione del modello: ' Robert_Downey_Jr.'
# Etichetta corretta: Robert_Downey_Jr
# OK
# -------------------------->
# 1/1 [==============================] - 0s 194ms/step
# [[["b' Philipp_Lahm'", 0.5086162], ["b' Gus_Hansen'", 0.05287851], ["b' Zoran_Kesi\\xc4\\x87'", 0.02926552], ["b' Luke_Hodge'", 0.025298253], ["b' Kevin_Zegers'", 0.024023162]]]
# Immagine: Philipp_Lahm_6_face_0.jpg
# Predizione del modello: ' Philipp_Lahm'
# Etichetta corretta: Philipp_Lahm
# OK
# -------------------------->
# 1/1 [==============================] - 0s 207ms/step
# [[["b' Edoardo_Leo'", 0.9147973], ["b' Mart\\xc3\\xadn_Karpan'", 0.008001696], ["b' Ricky_Paull_Goldin'", 0.007553829], ["b' Rodrigo_Santoro'", 0.0031273118], ["b' Rub\\xc3\\xa9n_Castro'", 0.0030595735]]]
# Immagine: Edoardo_Leo_10_face_0.jpg
# Predizione del modello: ' Edoardo_Leo'
# Etichetta corretta: Edoardo_Leo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Ezequiel_Lavezzi'", 0.27774036], ["b' Alex_Atala'", 0.056719176], ["b' Nino_Frassica'", 0.049404394], ["b' Charlie_Beck'", 0.02723799], ["b' Bill_Mays'", 0.027037239]]]
# Immagine: Ezequiel_Lavezzi_5_face_0.jpg
# Predizione del modello: ' Ezequiel_Lavezzi'
# Etichetta corretta: Ezequiel_Lavezzi
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Francesco_Pannofino'", 0.9868826], ["b' Guillermo_Capetillo'", 0.0073574125], ["b' T._Rajendar'", 0.0003365985], ["b' Carmine_Appice'", 0.00022508421], ["b' Celso_Pi\\xc3\\xb1a'", 0.00022030903]]]
# Immagine: Francesco_Pannofino_9_face_0.jpg
# Predizione del modello: ' Francesco_Pannofino'
# Etichetta corretta: Francesco_Pannofino
# OK
# -------------------------->
# 1/1 [==============================] - 0s 208ms/step
# [[["b' Orlando_Bloom'", 0.9820388], ["b' Micha\\xc5\\x82_\\xc5\\xbbew\\xc5\\x82akow'", 0.002356221], ["b' Krzysztof_Ho\\xc5\\x82owczyc'", 0.0010112596], ["b' Murat_Han'", 0.0005769065], ["b' Juan_Garc\\xc3\\xada_Postigo'", 0.0005041167]]]
# Immagine: Orlando_Bloom_6_face_0.jpg
# Predizione del modello: ' Orlando_Bloom'
# Etichetta corretta: Orlando_Bloom
# OK
# -------------------------->
# 1/1 [==============================] - 0s 192ms/step
# [[["b' Roberto_Bolle'", 0.9820545], ["b' Filip_Nikolic'", 0.0060255304], ["b' Jon-Erik_Hexum'", 0.000911229], ["b' Marc_Bartra'", 0.00073197804], ["b' Garrett_Neff'", 0.00061678246]]]
# Immagine: Roberto_Bolle_2_face_0.jpg
# Predizione del modello: ' Roberto_Bolle'
# Etichetta corretta: Roberto_Bolle
# OK
# -------------------------->
# 1/1 [==============================] - 0s 197ms/step
# ...
# Predizione del modello: ' Stephen_Mulhern'
# Etichetta corretta: Luke_Hemsworth
# -------------------------->
# 1/1 [==============================] - 0s 191ms/step
# [[["b' Massimo_Ranieri'", 0.9972459], ["b' Moacyr_Franco'", 9.445642e-05], ["b' Paul_Westerberg'", 8.006182e-05], ["b' Adam_Nawa\\xc5\\x82ka'", 5.703254e-05], ["b' Mika_Kojonkoski'", 5.5324876e-05]]]
# Immagine: Massimo_Ranieri_10_face_0.jpg
# Predizione del modello: ' Massimo_Ranieri'
# Etichetta corretta: Massimo_Ranieri
# OK
# -------------------------->
# 1/1 [==============================] - 0s 196ms/step
# [[["b' Massimo_Ranieri'", 0.9963012], ["b' Richard_Simmons'", 0.0005949234], ["b' Bob_Beckel'", 0.00024479887], ["b' Nathan_Lane'", 0.00012042259], ["b' Hartmut_Mehdorn'", 0.000115726914]]]
# Immagine: Massimo_Ranieri_1_face_0.jpg
# Predizione del modello: ' Massimo_Ranieri'
# Etichetta corretta: Massimo_Ranieri
# OK
# -------------------------->
# 1/1 [==============================] - 0s 211ms/step
# [[["b' Zendaya'", 0.7362898], ["b' Venus_Raj'", 0.119332194], ["b' Andien'", 0.07218005], ["b' Ava_DuVernay'", 0.0075727147], ["b' Dira_Paes'", 0.0070319735]]]
# Immagine: Zendaya_3_face_0.jpg
# Predizione del modello: ' Zendaya'
# Etichetta corretta: Zendaya
# OK
# -------------------------->
# 1/1 [==============================] - 0s 199ms/step
# [[["b' Roberto_Heras'", 0.051237237], ["b' Ian_McShane'", 0.03891943], ["b' Marko_Bulat'", 0.03886387], ["b' Jake_Weber'", 0.038176052], ["b' Derek_McInnes'", 0.028763626]]]
# Immagine: Tony_Montana_5_face_0.jpg
# Predizione del modello: ' Roberto_Heras'
# Etichetta corretta: Tony_Montana
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Ursula_von_der_Leyen'", 0.977382], ["b' Hilde_Crevits'", 0.0009339581], ["b' Miriam_Meckel'", 0.0008589833], ["b' Elena_Valenciano'", 0.000851615], ["b' Fiona_Phillips'", 0.0007552986]]]
# Immagine: Ursula_von_der_Leyen_5_face_0.jpg
# Predizione del modello: ' Ursula_von_der_Leyen'
# Etichetta corretta: Ursula_von_der_Leyen
# OK
# -------------------------->
# 1/1 [==============================] - 0s 204ms/step
# [[["b' Enrico_Letta'", 0.9200978], ["b' Algirdas_\\xc5\\xa0emeta'", 0.010638941], ["b' Ralf_Rangnick'", 0.0058045336], ["b' Claudio_Lotito'", 0.0042775343], ["b' Alfonso_Guerra'", 0.0030648625]]]
# Immagine: Enrico_Letta_3_face_0.jpg
# Predizione del modello: ' Enrico_Letta'
# Etichetta corretta: Enrico_Letta
# OK
# -------------------------->
# 1/1 [==============================] - 0s 313ms/step
# [[["b' Marco_Mengoni'", 0.9058289], ["b' Erom_Cordeiro'", 0.013210273], ["b' Damien_Sargue'", 0.0059758853], ["b' Bill_Mays'", 0.005280132], ["b' Joaquin_Phoenix'", 0.0035401154]]]
# Immagine: Marco_Mengoni_8_face_0.jpg
# Predizione del modello: ' Marco_Mengoni'
# Etichetta corretta: Marco_Mengoni
# OK
# -------------------------->
# 1/1 [==============================] - 0s 332ms/step
# [[["b' David_Beckham'", 0.8808137], ["b' Dani_Sordo'", 0.019391684], ["b' Felix_Neureuther'", 0.016517919], ["b' David_Villa'", 0.0055740825], ["b' Orlando_Bloom'", 0.0032847219]]]
# Immagine: David_Beckham_4_face_0.jpg
# Predizione del modello: ' David_Beckham'
# Etichetta corretta: David_Beckham
# OK
# -------------------------->
# 1/1 [==============================] - 0s 314ms/step
# [[["b' Ezio_Greggio'", 0.9979279], ["b' C\\xc4\\x83lin_Popescu-T\\xc4\\x83riceanu'", 0.00021843318], ["b' Fran\\xc3\\xa7ois_Cluzet'", 0.00014487839], ["b' \\xc3\\x93scar_Tab\\xc3\\xa1rez'", 0.00010878701], ["b' Dustin_Hoffman'", 9.878134e-05]]]
# Immagine: Ezio_Greggio_4_face_0.jpg
# Predizione del modello: ' Ezio_Greggio'
# Etichetta corretta: Ezio_Greggio
# OK
# -------------------------->
# 1/1 [==============================] - 0s 296ms/step
# [[["b' Ariana_Grande'", 0.795384], ["b' Josenid'", 0.040999886], ["b' Cinta_Laura'", 0.01092795], ["b' Jean-Michel_Baylet'", 0.007779205], ["b' Mai_Ph\\xc6\\xb0\\xc6\\xa1ng_Th\\xc3\\xbay'", 0.0075278943]]]
# Immagine: Ariana_Grande_1_face_0.jpg
# Predizione del modello: ' Ariana_Grande'
# Etichetta corretta: Ariana_Grande
# OK
# -------------------------->
# 1/1 [==============================] - 0s 325ms/step
# [[["b' Philipp_Lahm'", 0.98910904], ["b' Luke_Hodge'", 0.0024886564], ["b' Gonzalo_Fierro'", 0.0015313346], ["b' Gus_Hansen'", 0.00044895828], ["b' Lenny_Hayes'", 0.00039394893]]]
# Immagine: Philipp_Lahm_2_face_0.jpg
# Predizione del modello: ' Philipp_Lahm'
# Etichetta corretta: Philipp_Lahm
# OK
# -------------------------->
# 1/1 [==============================] - 0s 330ms/step
# [[["b' Rita_Dalla_Chiesa'", 0.9997732], ["b' Vanessa_Feltz'", 3.5070243e-05], ["b' Patrizia_Pellegrino'", 2.0805675e-05], ["b' Catharina_Elms\\xc3\\xa4ter-Sv\\xc3\\xa4rd'", 1.3903308e-05], ["b' Katie_Couric'", 7.525047e-06]]]
# Immagine: Rita_Dalla_Chiesa_9_face_0.jpg
# Predizione del modello: ' Rita_Dalla_Chiesa'
# Etichetta corretta: Rita_Dalla_Chiesa
# OK
# -------------------------->
# 1/1 [==============================] - 0s 324ms/step
# [[["b' Edoardo_Leo'", 0.8110619], ["b' \\xc3\\x9cmit_Karan'", 0.015675742], ["b' Mirko_Vu\\xc4\\x8dini\\xc4\\x87'", 0.009593764], ["b' Jorge_Garbajosa'", 0.008489356], ["b' Serdar_Kesimal'", 0.0065494645]]]
# Immagine: Edoardo_Leo_5_face_0.jpg
# Predizione del modello: ' Edoardo_Leo'
# Etichetta corretta: Edoardo_Leo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 307ms/step
# [[["b' Roberto_Bolle'", 0.8874584], ["b' Filip_Nikolic'", 0.011455041], ["b' Sean_Faris'", 0.0033365], ["b' Patrick_Sharp'", 0.0028970023], ["b' Jon-Erik_Hexum'", 0.0023925023]]]
# Immagine: Roberto_Bolle_6_face_0.jpg
# Predizione del modello: ' Roberto_Bolle'
# Etichetta corretta: Roberto_Bolle
# OK
# -------------------------->
# 1/1 [==============================] - 0s 337ms/step
# [[["b' Luca_Toni'", 0.96910536], ["b' Mirko_Vu\\xc4\\x8dini\\xc4\\x87'", 0.0033434865], ["b' Thomas_Dutronc'", 0.0016294215], ["b' Thomas_Eichin'", 0.0016046524], ["b' Nicolas_Prost'", 0.001509097]]]
# Immagine: Luca_Toni_9_face_0.jpg
# Predizione del modello: ' Luca_Toni'
# Etichetta corretta: Luca_Toni
# OK
# -------------------------->
# 1/1 [==============================] - 0s 320ms/step
# [[["b' Gian_Piero_Gasperini'", 0.59944916], ["b' Carlos_Queiroz'", 0.05824915], ["b' Jerry_Sandusky'", 0.042526834], ["b' Ranulph_Fiennes'", 0.03886355], ["b' Lo\\xc3\\xafck_Peyron'", 0.037682038]]]
# Immagine: Gian_Piero_Gasperini_1_face_0.jpg
# Predizione del modello: ' Gian_Piero_Gasperini'
# Etichetta corretta: Gian_Piero_Gasperini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 367ms/step
# [[["b' Vasco_Rossi'", 0.9815749], ["b' Chris_Squire'", 0.0025262788], ["b' Frank_Sch\\xc3\\xa4tzing'", 0.0008672398], ["b' Herb_Alpert'", 0.00034764886], ["b' Joacim_Cans'", 0.00033358092]]]
# Immagine: Vasco_Rossi_5_face_0.jpg
# Predizione del modello: ' Vasco_Rossi'
# Etichetta corretta: Vasco_Rossi
# OK
# -------------------------->
# 1/1 [==============================] - 0s 282ms/step
# [[["b' Cristiano_Ronaldo'", 0.81294715], ["b' Gonzalo_Fierro'", 0.009731987], ["b' Sean_Faris'", 0.006705193], ["b' Jamie_Soward'", 0.006459156], ["b' Marcus_Collins'", 0.0054930113]]]
# Immagine: Cristiano_Ronaldo_2_face_0.jpg
# Predizione del modello: ' Cristiano_Ronaldo'
# Etichetta corretta: Cristiano_Ronaldo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 201ms/step
# [[["b' Simon_Le_Bon'", 0.028895488], ["b' Jim_Breuer'", 0.025400424], ["b' Joaquin_Phoenix'", 0.019115498], ["b' William_Porterfield'", 0.018960228], ["b' Alexander_Klaws'", 0.015881293]]]
# Immagine: Matthew_Perry_5_face_0.jpg
# Predizione del modello: ' Simon_Le_Bon'
# Etichetta corretta: Matthew_Perry
# -------------------------->
# 1/1 [==============================] - 0s 193ms/step
# [[["b' Valentina_Vezzali'", 0.98991007], ["b' Loredana_Errore'", 0.00030906717], ["b' Selina_Gasparin'", 0.0003047707], ["b' Monica_Lierhaus'", 0.00025012702], ["b' Mariya_Savinova'", 0.0001868966]]]
# Immagine: Valentina_Vezzali_8_face_0.jpg
# Predizione del modello: ' Valentina_Vezzali'
# Etichetta corretta: Valentina_Vezzali
# OK
# -------------------------->
# 1/1 [==============================] - 0s 198ms/step
# [[["b' Ryan_Gosling'", 0.99883014], ["b' Philippe_Cousteau'", 0.00027475308], ["b' Johnny_Reid'", 6.3513e-05], ["b' Chris_Hardwick'", 4.3924327e-05], ["b' Gaizka_Mendieta'", 2.8234945e-05]]]
# Immagine: Ryan_Gosling_3_face_0.jpg
# Predizione del modello: ' Ryan_Gosling'
# Etichetta corretta: Ryan_Gosling
# OK
# -------------------------->
# 1/1 [==============================] - 0s 198ms/step
# [[["b' Laura_Chiatti'", 0.97428584], ["b' Rachel_Weisz'", 0.0015834358], ["b' Lacey_Schwimmer'", 0.0010634224], ["b' Ana_Beatriz_Barros'", 0.0008987914], ["b' Valerie_Leon'", 0.0008071811]]]
# Immagine: Laura_Chiatti_5_face_0.jpg
# Predizione del modello: ' Laura_Chiatti'
# Etichetta corretta: Laura_Chiatti
# OK
# -------------------------->
# 1/1 [==============================] - 0s 192ms/step
# [[["b' Michael_B._Jordan'", 0.37449318], ["b' Dorlan_Pab\\xc3\\xb3n'", 0.2424206], ["b' Shani_Davis'", 0.06377793], ["b' Reimond_Manco'", 0.05161019], ["b' Dionte_Christmas'", 0.011523459]]]
# Immagine: Michael_B._Jordan_2_face_0.jpg
# Predizione del modello: ' Michael_B._Jordan'
# Etichetta corretta: Michael_B._Jordan
# OK
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Luca_Argentero'", 0.9672235], ["b' Gr\\xc3\\xa9gory_Fitoussi'", 0.0030542882], ["b' Rodolfo_Sancho'", 0.0021730682], ["b' Rafael_Novoa'", 0.0010850953], ["b' Leonardo_Sbaraglia'", 0.0008371232]]]
# Immagine: Luca_Argentero_4_face_0.jpg
# Predizione del modello: ' Luca_Argentero'
# Etichetta corretta: Luca_Argentero
# OK
# -------------------------->
# 1/1 [==============================] - 0s 198ms/step
# [[["b' Luisana_Lopilato'", 0.9998752], ["b' Vahina_Giocante'", 9.469692e-06], ["b' Kelsey_Chow'", 4.7474546e-06], ["b' Elsa_Pataky'", 4.6354107e-06], ["b' Jessica_Origliasso'", 4.3270566e-06]]]
# Immagine: Luisana_Lopilato_6_face_0.jpg
# Predizione del modello: ' Luisana_Lopilato'
# Etichetta corretta: Luisana_Lopilato
# OK
# -------------------------->
# 1/1 [==============================] - 0s 199ms/step
# [[["b' Francesca_Schiavone'", 0.99666023], ["b' Karen_Carney'", 0.0006396775], ["b' Paulinho'", 9.443895e-05], ["b' Enrique_Barza'", 7.389313e-05], ["b' Emma_Moffatt'", 6.353242e-05]]]
# Immagine: Francesca_Schiavone_5_face_0.jpg
# Predizione del modello: ' Francesca_Schiavone'
# Etichetta corretta: Francesca_Schiavone
# OK
# -------------------------->
# 1/1 [==============================] - 0s 207ms/step
# [[["b' Vanessa_Incontrada'", 0.99708503], ["b' Irina_Bj\\xc3\\xb6rklund'", 0.00023274876], ["b' Helena_Noguerra'", 0.00016133602], ["b' Raquel_S\\xc3\\xa1nchez-Silva'", 0.00011572588], ["b' Carolina_Ferraz'", 0.000105529616]]]
# Immagine: Vanessa_Incontrada_2_face_0.jpg
# Predizione del modello: ' Vanessa_Incontrada'
# Etichetta corretta: Vanessa_Incontrada
# OK
# -------------------------->
# 1/1 [==============================] - 0s 194ms/step
# [[["b' Giorgia_Meloni'", 0.9475566], ["b' Natasha_Hamilton'", 0.005511689], ["b' Will_i_Am'", 0.0050208387], ["b' Susan_Sarandon'", 0.004353665], ["b' Deborah_Voigt'", 0.002646874]]]
# Immagine: Giorgia_Meloni_4_face_0.jpg
# Predizione del modello: ' Giorgia_Meloni'
# Etichetta corretta: Giorgia_Meloni
# OK
# -------------------------->
# 1/1 [==============================] - 0s 201ms/step
# [[["b' Martin_Kaymer'", 0.15430886], ["b' Al_Murray'", 0.10538606], ["b' Nicholas_Hoult'", 0.08232765], ["b' Nicolas_Mas'", 0.060396645], ["b' Clayne_Crawford'", 0.0380187]]]
# Immagine: Leonardo_DiCaprio_8_face_0.jpg
# Predizione del modello: ' Martin_Kaymer'
# Etichetta corretta: Leonardo_DiCaprio
# -------------------------->
# 1/1 [==============================] - 0s 197ms/step
# [[["b' Andrea_Pirlo'", 0.8651671], ["b' Vuk_Dra\\xc5\\xa1kovi\\xc4\\x87'", 0.008206436], ["b' Gines_Garcia_Millan'", 0.00692061], ["b' Bruno_Bichir'", 0.0064343745], ["b' Rodolfo_Sancho'", 0.0040796488]]]
# Immagine: Andrea_Pirlo_1_face_0.jpg
# Predizione del modello: ' Andrea_Pirlo'
# Etichetta corretta: Andrea_Pirlo
# OK
# -------------------------->
# 1/1 [==============================] - 0s 193ms/step
# [[["b' Monica_Guerritore'", 0.27030304], ["b' Gabriela_Sabatini'", 0.058288068], ["b' Gia_Carangi'", 0.046149645], ["b' Stella_Tennant'", 0.027604636], ["b' Elli_Medeiros'", 0.022585472]]]
# Immagine: Michael_Jackson_5_face_0.jpg
# Predizione del modello: ' Monica_Guerritore'
# Etichetta corretta: Michael_Jackson
# -------------------------->
# 1/1 [==============================] - 0s 195ms/step
# [[["b' Micaela_Ramazzotti'", 0.94838506], ["b' Elsa_Slvan'", 0.004398605], ["b' Fabiana_Tambosi'", 0.0033140124], ["b' Alexandra_Paul'", 0.003184697], ["b' Carlson_Young'", 0.0017189771]]]
# Immagine: Micaela_Ramazzotti_6_face_0.jpg
# Predizione del modello: ' Micaela_Ramazzotti'
# Etichetta corretta: Micaela_Ramazzotti
# OK
# -------------------------->
# 1/1 [==============================] - 0s 200ms/step
# [[["b' Emanuele_Giaccherini'", 0.91119105], ["b' Piotr_Adamczyk'", 0.008650025], ["b' Tom\\xc3\\xa1\\xc5\\xa1_Klus'", 0.0074340026], ["b' Michelle_Jenner'", 0.0054705804], ["b' Ben_Mee'", 0.0041416646]]]
# Immagine: Emanuele_Giaccherini_3_face_0.jpg
# Predizione del modello: ' Emanuele_Giaccherini'
# Etichetta corretta: Emanuele_Giaccherini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 232ms/step
# [[["b' Edgar_Savisaar'", 0.17027713], ["b' Agust\\xc3\\xadn_Carstens'", 0.0569395], ["b' L.A._Reid'", 0.04527278], ["b' Harry_Hill'", 0.039921056], ["b' Gino_Iorgulescu'", 0.031209705]]]
# Immagine: Gigi_DAlessio_1_face_0.jpg
# Predizione del modello: ' Edgar_Savisaar'
# Etichetta corretta: Gigi_DAlessio
# -------------------------->
# 1/1 [==============================] - 0s 193ms/step
# [[["b' Robert_Downey_Jr.'", 0.9992913], ["b' Llu\\xc3\\xads_Llach'", 4.2779055e-05], ["b' Rafael_Novoa'", 2.8234785e-05], ["b' Taika_Waititi'", 1.9278097e-05], ["b' Blake_Ritson'", 1.9208745e-05]]]
# Immagine: Robert_Downey_Jr_3_face_0.jpg
# Predizione del modello: ' Robert_Downey_Jr.'
# Etichetta corretta: Robert_Downey_Jr
# OK
# -------------------------->
# 1/1 [==============================] - 0s 193ms/step
# [[["b' Christian_Berkel'", 0.09657119], ["b' Daniel_Landa'", 0.06907459], ["b' Royler_Gracie'", 0.068841524], ["b' Arturo_Brachetti'", 0.06634172], ["b' Varujan_Vosganian'", 0.05857311]]]
# Immagine: Luca_Parmitano_2_face_0.jpg
# Predizione del modello: ' Christian_Berkel'
# Etichetta corretta: Luca_Parmitano
# -------------------------->
# 1/1 [==============================] - 0s 196ms/step
# [[["b' Lorenzo_Insigne'", 0.6294087], ["b' Maxi_Biancucchi'", 0.03182006], ["b' H\\xc3\\xa9lder_Postiga'", 0.027106762], ["b' Pep_Guardiola'", 0.026215812], ["b' Serdar_Kesimal'", 0.019314092]]]
# Immagine: Lorenzo_Insigne_6_face_0.jpg
# Predizione del modello: ' Lorenzo_Insigne'
# Etichetta corretta: Lorenzo_Insigne
# OK
# -------------------------->
# 1/1 [==============================] - 0s 188ms/step
# [[["b' James_Franco'", 0.10499963], ["b' Ryan_Peake'", 0.09355905], ["b' Rocco_DiSpirito'", 0.058755554], ["b' S\\xc3\\xa1mer_Issa'", 0.054119896], ["b' Mark_Hapka'", 0.042174548]]]
# Immagine: Matteo_Darmian_1_face_0.jpg
# Predizione del modello: ' James_Franco'
# Etichetta corretta: Matteo_Darmian
# -------------------------->
# 1/1 [==============================] - 0s 189ms/step
# [[["b' Lorella_Cuccarini'", 0.97974753], ["b' Sandrine_Corman'", 0.003325561], ["b' Tracy_Tweed'", 0.0018805339], ["b' Sarah_Harding'", 0.0013562596], ["b' M\\xc3\\xb3nica_Cruz'", 0.0012215589]]]
# Immagine: Lorella_Cuccarini_1_face_0.jpg
# Predizione del modello: ' Lorella_Cuccarini'
# Etichetta corretta: Lorella_Cuccarini
# OK
# -------------------------->
# 1/1 [==============================] - 0s 198ms/step
# [[["b' Randy_Orton'", 0.9892174], ["b' Juan_Gil_Navarro'", 0.0006749039], ["b' Albert_Sosnowski'", 0.000615203], ["b' Vaidas_Baumila'", 0.0005860866], ["b' Cl\\xc3\\xa9mentine_C\\xc3\\xa9lari\\xc3\\xa9'", 0.00045825783]]]
# Immagine: Randy_Orton_3_face_0.jpg
# Predizione del modello: ' Randy_Orton'
# Etichetta corretta: Randy_Orton
# OK
# -------------------------->
#
#
#
#
# Test Accuracy: 0.8891089108910891
# Numero di predizioni corrette: 898
# Numero di immagini processate: 1010
